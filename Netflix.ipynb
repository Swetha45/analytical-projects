# %% [markdown]
# # Data Analysis on Netflix

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plot
import seaborn as sb

# %% [markdown]
# # read CSV file

# %%
csvfile = pd.read_csv(r"C:netflix_data.csv")
csvfile
# Out:
#        show_id     type                                        title  \
# 0     81145628    Movie      Norm of the North: King Sized Adventure
# 1     80117401    Movie                   Jandino: Whatever it Takes
# 2     70234439  TV Show                           Transformers Prime
# 3     80058654  TV Show             Transformers: Robots in Disguise
# 4     80125979    Movie                                 #realityhigh
# ...        ...      ...                                          ...
# 6229  80000063  TV Show                                 Red vs. Blue
# 6230  70286564  TV Show                                        Maron
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 6233  70153404  TV Show                                      Friends
#
#                       director  \
# 0     Richard Finn, Tim Maltby
# 1                          NaN
# 2                          NaN
# ...

# %%
csvfile.index
# Out:
# RangeIndex(start=0, stop=6234, step=1)

# %% [markdown]
# ###  The data types of csv file columns (int, float64, object)

# %%
csvfile.dtypes
# Out:
# show_id          int64
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
# To know the column labels of the DataFrame use -- columns method

# %%
csvfile.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
# Make csv columns first character to Capital

# %%
csvfile.columns = map(str.title, csvfile.columns)
print(csvfile)
# Out:
#        Show_Id     Type                                        Title  \
# 0     81145628    Movie      Norm of the North: King Sized Adventure
# 1     80117401    Movie                   Jandino: Whatever it Takes
# 2     70234439  TV Show                           Transformers Prime
# 3     80058654  TV Show             Transformers: Robots in Disguise
# 4     80125979    Movie                                 #realityhigh
# ...        ...      ...                                          ...
# 6229  80000063  TV Show                                 Red vs. Blue
# 6230  70286564  TV Show                                        Maron
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 6233  70153404  TV Show                                      Friends
#
#                       Director  \
# 0     Richard Finn, Tim Maltby
# 1                          NaN
# 2                          NaN
# ...

# %%
csvfile
# Out:
#        Show_Id     Type                                        Title  \
# 0     81145628    Movie      Norm of the North: King Sized Adventure
# 1     80117401    Movie                   Jandino: Whatever it Takes
# 2     70234439  TV Show                           Transformers Prime
# 3     80058654  TV Show             Transformers: Robots in Disguise
# 4     80125979    Movie                                 #realityhigh
# ...        ...      ...                                          ...
# 6229  80000063  TV Show                                 Red vs. Blue
# 6230  70286564  TV Show                                        Maron
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 6233  70153404  TV Show                                      Friends
#
#                       Director  \
# 0     Richard Finn, Tim Maltby
# 1                          NaN
# 2                          NaN
# ...

# %%
# Remove null values from DataFrame

# %%
 dropNullValues = csvfile.dropna()

# %%
# After removing the null values the DataFrame have below rows

# %%
dropNullValues
# Out:
#        Show_Id     Type                                    Title  \
# 0     81145628    Movie  Norm of the North: King Sized Adventure
# 4     80125979    Movie                             #realityhigh
# 6     70304989    Movie                                 Automata
# 7     80164077    Movie       Fabrizio Copano: Solo pienso en mi
# 9     70304990    Movie                              Good People
# ...        ...      ...                                      ...
# 6142  80063224  TV Show            The Great British Baking Show
# 6158  80164216  TV Show  Miraculous: Tales of Ladybug & Cat Noir
# 6167  80115328  TV Show                             Sacred Games
# 6182  80176842  TV Show                         Men on a Mission
# 6213  80126599  TV Show                         Leyla and Mecnun
#
#                                   Director  \
# 0                 Richard Finn, Tim Maltby
# 4                         Fernando Lebrija
# 6                              Gabe Ibáñez
# ...

# %%
# Show unique rows and columns

# %%
dropDuplicateValues = dropNullValues.drop_duplicates(keep='first')
dropDuplicateValues
# Out:
#        Show_Id     Type                                    Title  \
# 0     81145628    Movie  Norm of the North: King Sized Adventure
# 4     80125979    Movie                             #realityhigh
# 6     70304989    Movie                                 Automata
# 7     80164077    Movie       Fabrizio Copano: Solo pienso en mi
# 9     70304990    Movie                              Good People
# ...        ...      ...                                      ...
# 6142  80063224  TV Show            The Great British Baking Show
# 6158  80164216  TV Show  Miraculous: Tales of Ladybug & Cat Noir
# 6167  80115328  TV Show                             Sacred Games
# 6182  80176842  TV Show                         Men on a Mission
# 6213  80126599  TV Show                         Leyla and Mecnun
#
#                                   Director  \
# 0                 Richard Finn, Tim Maltby
# 4                         Fernando Lebrija
# 6                              Gabe Ibáñez
# ...

# %%
# find a movie name which has max duration

# %%
sortValues = dropDuplicateValues.sort_values(by = 'Duration' , ascending=True )
sortValues.head()
# Out:
#        Show_Id   Type                                              Title  \
# 2085  80171733  Movie                                    Roxanne Roxanne
# 1978  70100381  Movie                                    Bedtime Stories
# 4844  70012316  Movie  InuYasha the Movie: Affections Touching Across...
# 5356  80112518  Movie                                    I, Daniel Blake
# 1970  60037606  Movie                               Benji: Off the Leash
#
#                Director                                               Cast  \
# 2085    Michael Larnell  Chanté Adams, Mahershala Ali, Nia Long, Elvis ...
# 1978      Adam Shankman  Adam Sandler, Keri Russell, Guy Pearce, Russel...
# 4844  Toshiya Shinohara  Kappei Yamaguchi, Satsuki Yukino, Koji Tsujita...
# 5356          Ken Loach  Dave Johns, Hayley Squires, Briana Shann, Dyla...
# 1970           Joe Camp  Nick Whitaker, Chris Kendrick, Randall Newsome...
#
#                               Country Date_Added  Release_Year Rating  \
# ...

# %%
import matplotlib.pyplot as plot
import seaborn as sb

# %%
sns.set()

# %%
# Find a movie name which has highest duration

# %%
sortValues[['Title', 'Release_Year', 'Duration']].sort_values(by=['Release_Year'], ascending=True).head(5)
# Out:
#                                          Title  Release_Year Duration
# 2085                           Roxanne Roxanne          2018  100 min
# 313                         Olmo & the Seagull          2018   82 min
# 4276                            Fun Mom Dinner          2018   82 min
# 2170                            Chicken Little          2018   82 min
# 4011  Cats & Dogs: The Revenge of Kitty Galore          2018   82 min

# %%
sortValues['Duration'].max()
# Out:
# '99 min'

# %%
sortValues.groupby(['Title', 'Release_Year'])

# %%
s2 = data4.groupby("School State")["Donation Amount"].mean().sort_values(ascending = False).head(10)
