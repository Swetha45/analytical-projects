# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plot
import seaborn as sb

# %%
donations = pd.read_csv(r"C:filepath\Donations.csv")
donations.head()
# Out:
#                          Project ID                       Donation ID  \
# 0  000009891526c0ade7180f8423792063  688729120858666221208529ee3fc18e
# 1  000009891526c0ade7180f8423792063  dcf1071da3aa3561f91ac689d1f73dee
# 2  000009891526c0ade7180f8423792063  18a234b9d1e538c431761d521ea7799d
# 3  000009891526c0ade7180f8423792063  38d2744bf9138b0b57ed581c76c0e2da
# 4  000009891526c0ade7180f8423792063  5a032791e31167a70206bfb86fb60035
#
#                            Donor ID Donation Included Optional Donation  \
# 0  1f4b5b6e68445c6c4a0509b3aca93f38                                  No
# 1  4aaab6d244bf3599682239ed5591af8a                                 Yes
# 2  0b0765dc9c759adc48a07688ba25e94e                                 Yes
# 3  377944ad61f72d800b25ec1862aec363                                 Yes
# 4  6d5b22d39e68c656071a842732c63a0c                                 Yes
#
#    Donation Amount  Donor Cart Sequence Donation Received Date
# ...

# %%
donars = pd.read_csv(r"C:filepath\Donors.csv")
donars.head()
# Out:
#                            Donor ID    Donor City Donor State  \
# 0  00000ce845c00cbf0686c992fc369df4      Evanston    Illinois
# 1  00002783bc5d108510f3f9666c8b1edd    Appomattox       other
# 2  00002d44003ed46b066607c5455a999a        Winton  California
# 3  00002eb25d60a09c318efbd0797bffb5  Indianapolis     Indiana
# 4  0000300773fe015f870914b42528541b      Paterson  New Jersey
#
#   Donor Is Teacher Donor Zip
# 0               No       602
# 1               No       245
# 2              Yes       953
# 3               No       462
# 4               No       075

# %%
Resources = pd.read_csv(r"C:filepath\Resources.csv")
Resources.head()
# Out:
#                          Project ID  \
# 0  000009891526c0ade7180f8423792063
# 1  00000ce845c00cbf0686c992fc369df4
# 2  00002d44003ed46b066607c5455a999a
# 3  00002d44003ed46b066607c5455a999a
# 4  00002d44003ed46b066607c5455a999a
#
#                           Resource Item Name  Resource Quantity  \
# 0                  chair move and store cart                1.0
# 1            sony mdr zx100 blk   headphones               40.0
# 2  gaiam kids stay-n-play balance ball, grey                4.0
# 3    cf520x - giant comfy pillows - set of 4                1.0
# 4              serta lounger, mini, sky blue                1.0
#
#    Resource Unit Price          Resource Vendor Name
# 0               350.00                           NaN
# 1                12.86                         CDW-G
# 2                19.00               Amazon Business
# 3               269.00  Lakeshore Learning Materials
# 4               131.85               Amazon Business

# %%
Schools = pd.read_csv(r"C:filepath\Schools.csv")
Schools.head()
# Out:
#                           School ID                             School Name  \
# 0  00003e0fdd601b8ea0a6eb44057b9c5e              Capon Bridge Middle School
# 1  00004e32a448b4832e1b993500bf0731  The Woodlands College Park High School
# 2  0002021bb799f28de224f1acc1ff08c4        Samantha Smith Elementary School
# 3  0004604f675212a8cac1161338265196            Kingsbury Country Day School
# 4  0004c9d50bcf0cea990f844e58b5e2c3              Redwater Elementary School
#
#   School Metro Type  School Percentage Free Lunch   School State  School Zip  \
# 0             rural                          56.0  West Virginia       26711
# 1             urban                          41.0          Texas       77384
# 2          suburban                           2.0     Washington       98074
# 3           unknown                          76.0       Michigan       48370
# 4             rural                          50.0          Texas       75573
#
# ...

# %%
teachers = pd.read_csv(r"C:filepath\Teachers.csv")
teachers.head()
# Out:
#                          Teacher ID Teacher Prefix  \
# 0  00000f7264c27ba6fea0c837ed6aa0aa           Mrs.
# 1  00002d44003ed46b066607c5455a999a           Mrs.
# 2  00006084c3d92d904a22e0a70f5c119a            Mr.
# 3  0000a9af8b6b9cc9e41f53322a8b8cf1            Ms.
# 4  0000d4777d14b33a1406dd6c9019fe89            Ms.
#
#   Teacher First Project Posted Date
# 0                         8/21/2013
# 1                        10/23/2016
# 2                          9/8/2016
# 3                        10/25/2015
# 4                         2/10/2017

# %%
donations.dtypes
# Out:
# Project ID                              object
# Donation ID                             object
# Donor ID                                object
# Donation Included Optional Donation     object
# Donation Amount                        float64
# Donor Cart Sequence                      int64
# Donation Received Date                  object
# dtype: object

# %%
donations.size
# Out:
# 32815188

# %%
donations.shape
# Out:
# (4687884, 7)

# %%
# remove the null values from donations dataframe

# %%
dropNullValues = donations.dropna()
dropNullValues
# Out:
#                                Project ID                       Donation ID  \
# 0        000009891526c0ade7180f8423792063  688729120858666221208529ee3fc18e
# 1        000009891526c0ade7180f8423792063  dcf1071da3aa3561f91ac689d1f73dee
# 2        000009891526c0ade7180f8423792063  18a234b9d1e538c431761d521ea7799d
# 3        000009891526c0ade7180f8423792063  38d2744bf9138b0b57ed581c76c0e2da
# 4        000009891526c0ade7180f8423792063  5a032791e31167a70206bfb86fb60035
# ...                                   ...                               ...
# 4687879  ffff98098650c5e07fa7f40030fbe9e2  0a2835947d01029f83a7314a07976c0f
# 4687880  ffff9bb21699f79266cc7cbc208890a0  ff32e8459ddee3351b71c264fcc36da6
# 4687881  ffffd8f0fbfa10b99efe90a5ee13c5df  eb5b81e658e82a7ab1396addf4a098c0
# 4687882  fffffcc42d1bf7ab742a4fa2d820f9f0  b6a48abb6b386519fdf5ad08aa0d1ed0
# 4687883  fffffcc42d1bf7ab742a4fa2d820f9f0  9cf7022dc0795da640b32496400e82be
#
# ...

# %%
# check does this dataframe have null values

# %%
donations.isnull().sum()
# Out:
# Project ID                             0
# Donation ID                            0
# Donor ID                               0
# Donation Included Optional Donation    0
# Donation Amount                        0
# Donor Cart Sequence                    0
# Donation Received Date                 0
# dtype: int64

# %%
# after removing the null values check the shape of dataframe

# %%
type(dropNullValues)
# Out:
# pandas.core.frame.DataFrame

# %%
dropNullValues.shape
# Out:
# (4687884, 7)

# %%
# drop duplicate values

# %%
dropDuplicate = donations.drop_duplicates(keep='first')

# %%
dropDuplicate.shape
# Out:
# (4687884, 7)

# %%
donations.describe()
# Out:
#        Donation Amount  Donor Cart Sequence
# count     4.687884e+06         4.687884e+06
# mean      6.066879e+01         1.430545e+02
# std       1.668996e+02         8.723086e+02
# min       1.000000e-02         1.000000e+00
# 25%       1.482000e+01         1.000000e+00
# 50%       2.500000e+01         2.000000e+00
# 75%       5.000000e+01         1.200000e+01
# max       6.000000e+04         1.811600e+04

# %%
donations.columns.tolist()
# Out:
# ['Project ID',
#  'Donation ID',
#  'Donor ID',
#  'Donation Included Optional Donation',
#  'Donation Amount',
#  'Donor Cart Sequence',
#  'Donation Received Date']

# %%
# take scholl dataframe

# %%
Schools.isnull().sum()
# Out:
# School ID                          0
# School Name                        0
# School Metro Type                  0
# School Percentage Free Lunch    1141
# School State                       0
# School Zip                         0
# School City                      227
# School County                      2
# School District                    0
# dtype: int64

# %%
# Percentage Free Lunch and City columns have null values.

# %%
schollnullValues = Schools.dropna()
schollnullValues
# Out:
#                               School ID  \
# 0      00003e0fdd601b8ea0a6eb44057b9c5e
# 1      00004e32a448b4832e1b993500bf0731
# 2      0002021bb799f28de224f1acc1ff08c4
# 3      0004604f675212a8cac1161338265196
# 4      0004c9d50bcf0cea990f844e58b5e2c3
# ...                                 ...
# 72988  fffb8fb6bf0d738b95a29106d4fa2319
# 72989  fffce2124c11a8372eb23948a3471546
# 72990  ffff8bee61b72c484b10e43aa9e35bc9
# 72991  ffff9bb21699f79266cc7cbc208890a0
# 72992  ffffc2e1225ac40a3ace9b8562115c9b
#
#                                   School Name School Metro Type  \
# 0                  Capon Bridge Middle School             rural
# 1      The Woodlands College Park High School             urban
# 2            Samantha Smith Elementary School          suburban
# 3                Kingsbury Country Day School           unknown
# 4                  Redwater Elementary School             rural
# ...                                       ...               ...
# ...

# %%
schollnullValues.isnull().sum()
# Out:
# School ID                       0
# School Name                     0
# School Metro Type               0
# School Percentage Free Lunch    0
# School State                    0
# School Zip                      0
# School City                     0
# School County                   0
# School District                 0
# dtype: int64

# %%
schollnullValues = Schools.drop_duplicates(keep='first')

# %%
schollnullValues.shape
# Out:
# (72993, 9)

# %%
type(schollnullValues)
# Out:
# pandas.core.frame.DataFrame

# %%
schollnullValues.head()
# Out:
#                           School ID                             School Name  \
# 0  00003e0fdd601b8ea0a6eb44057b9c5e              Capon Bridge Middle School
# 1  00004e32a448b4832e1b993500bf0731  The Woodlands College Park High School
# 2  0002021bb799f28de224f1acc1ff08c4        Samantha Smith Elementary School
# 3  0004604f675212a8cac1161338265196            Kingsbury Country Day School
# 4  0004c9d50bcf0cea990f844e58b5e2c3              Redwater Elementary School
#
#   School Metro Type  School Percentage Free Lunch   School State  School Zip  \
# 0             rural                          56.0  West Virginia       26711
# 1             urban                          41.0          Texas       77384
# 2          suburban                           2.0     Washington       98074
# 3           unknown                          76.0       Michigan       48370
# 4             rural                          50.0          Texas       75573
#
# ...

# %%
# show the top 10 scholl city  providing a free lunch

# %%
citynames = schollnullValues["School City"].value_counts().sort_values(ascending = False).head(10)
citynames
# Out:
# New York City    2051
# Houston           729
# Chicago           725
# Los Angeles       644
# San Antonio       379
# Philadelphia      371
# Dallas            352
# Phoenix           312
# Baltimore         296
# Columbus          288
# Name: School City, dtype: int64

# %%
# Make plots of DataFrame

# %%
type(citynames)
# Out:
# pandas.core.series.Series

# %%
my_colors = list(['blue', 'red', 'green', 'yellow', 'grey'])
citynames.plot.bar(stacked=True, color= my_colors)
plot.xlabel("City Names")
plot.ylabel("Number of scholls")
plot.title("Total Number of Schools in City")
# Out:
# Text(0.5, 1.0, 'Total Number of Schools in City')

# %%
schollAgg = Schools.groupby("School Name")["School Percentage Free Lunch"].min().tail(5)
schollAgg
# Out:
# School Name
# Zuni Hills Elementary School    30.0
# Zuni Middle School              93.0
# Zwink Elementary School         48.0
# Zwolle Elementary School        83.0
# Zwolle High School              78.0
# Name: School Percentage Free Lunch, dtype: float64

# %%
schollAgg.plot.barh()
plot.xlabel("School Names")
plot.ylabel("Free lunch percentage")
# Out:
# Text(0, 0.5, 'Free lunch percentage')

# %%
# combine the dataframes schools, teachers, donors, resources, donations

# %%
projects = pd.read_csv(r"C:\Users\shwet\OneDrive\Desktop\Jobs\phyton\pandas_project\Donaros\Projects.csv")
projects
# Out:
#                                Project ID                         School ID  \
# 0        7685f0265a19d7b52a470ee4bac883ba  e180c7424cb9c68cb49f141b092a988f
# 1        f9f4af7099061fb4bf44642a03e5c331  08b20f1e2125103ed7aa17e8d76c71d4
# 2        afd99a01739ad5557b51b1ba0174e832  1287f5128b1f36bf8434e5705a7cc04d
# 3        c614a38bb1a5e68e2ae6ad9d94bb2492  900fec9cd7a3188acbc90586a09584ef
# 4        ec82a697fab916c0db0cdad746338df9  3b200e7fe3e6dde3c169c02e5fb5ae86
# ...                                   ...                               ...
# 1110012  9f666ce758b2b1ef81013c9ba44ad187  0b642ece7cc59dc44eebdde5bd76d550
# 1110013  e793f983654503778ee5ca84c7949ba3  db672a68b83c7825123dfd757cd82fce
# 1110014  e4f265c55af985eb36b404dc3c7d4bfa  ca45c121a0e1c1450a76f083a37a6cc5
# 1110015  09bec6536169086e7c5441eb703e292a  41c4a4fb5712361c2efb1b24a6f4830a
# 1110016  825bc64a9ada078ca216507d1e5a2a0a  a2620081d137bb850f9dcacdec7cd1bd
#
# ...

# %%
merge1 = pd.merge(projects, donations, how = "inner", on = "Project ID")

# %%
merge2 = pd.merge(merge1, donors, how = "inner", on = "donarID")
merge2

# %%
merge3 = pd.merge(merge2, teachers, how = "inner", on = "Teacher ID")
merge3

# %%
plot.hist(merge3.groupby())

# %%
s2.plot.barh()
plt.xlabel("Average Donations Per Project ( in dollars )")
plt.ylabel("States")
plt.axvline(data4.groupby("School State")["Donation Amount"].mean().mean(), color = "blue", linewidth = 2 )
plt.title("Top 10 States that gather donations more than average")
plt.tight_layout()
plt.margins(0.05)
